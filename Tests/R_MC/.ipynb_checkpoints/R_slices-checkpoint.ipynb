# %% [markdown]
# # Wjets

# %% [markdown]
# ## Pesati

# %%
import yaml
import pandas as pd
import matplotlib.pyplot as plt
from os import listdir

# %%
with open("Wjets/slice/R_pesati/Wmunu_0_70.txt", "r") as f:
    Wmunu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_0_70.txt", "r") as f:
    Wenu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_0_70.txt", "r") as f:
    Wtaunu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wmunu_70_140.txt", "r") as f:
    Wmunu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_70_140.txt", "r") as f:
    Wenu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_70_140.txt", "r") as f:
    Wtaunu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wmunu_140_280.txt", "r") as f:
    Wmunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_140_280.txt", "r") as f:
    Wenu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_140_280.txt", "r") as f:
    Wtaunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wmunu_280_500.txt", "r") as f:
    Wmunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_280_500.txt", "r") as f:
    Wenu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_280_500.txt", "r") as f:
    Wtaunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wmunu_500_1000.txt", "r") as f:
    Wmunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_500_1000.txt", "r") as f:
    Wenu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_500_1000.txt", "r") as f:
    Wtaunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wmunu_1000.txt", "r") as f:
    Wmunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_pesati/Wenu_1000.txt", "r") as f:
    Wenu_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_pesati/Wtaunu_1000.txt", "r") as f:
    Wtaunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

# %%
# pt 0_70 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_0_70[list(Wmunu_0_70.keys())[i]]["R_MC"])
    yerr.append(Wmunu_0_70[list(Wmunu_0_70.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_0_70[list(Wenu_0_70.keys())[i]]["R_MC"]
    yerr[i] = Wenu_0_70[list(Wenu_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_0_70[list(Wtaunu_0_70.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_0_70[list(Wtaunu_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 


#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_0_70.keys()))), list(Wmunu_0_70.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)



###############################################################################################
# pt 70 - 140 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_70_140[list(Wmunu_70_140.keys())[i]]["R_MC"])
    yerr.append(Wmunu_70_140[list(Wmunu_70_140.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_70_140[list(Wenu_70_140.keys())[i]]["R_MC"]
    yerr[i] = Wenu_70_140[list(Wenu_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_70_140[list(Wtaunu_70_140.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_70_140[list(Wtaunu_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_70_140.keys()))), list(Wmunu_70_140.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)



###############################################################################################
# pt 140 - 280 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_140_280[list(Wmunu_140_280.keys())[i]]["R_MC"])
    yerr.append(Wmunu_140_280[list(Wmunu_140_280.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_140_280[list(Wenu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Wenu_140_280[list(Wenu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_140_280[list(Wtaunu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_140_280[list(Wtaunu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_140_280.keys()))), list(Wmunu_140_280.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


###############################################################################################
# pt 280 - 500 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_280_500[list(Wmunu_280_500.keys())[i]]["R_MC"])
    yerr.append(Wmunu_280_500[list(Wmunu_280_500.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_280_500[list(Wenu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Wenu_280_500[list(Wenu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_280_500[list(Wtaunu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_280_500[list(Wtaunu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_280_500.keys()))), list(Wmunu_280_500.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)



###############################################################################################
# pt 500 - 1000 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_500_1000[list(Wmunu_500_1000.keys())[i]]["R_MC"])
    yerr.append(Wmunu_500_1000[list(Wmunu_500_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_500_1000[list(Wenu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Wenu_500_1000[list(Wenu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_500_1000[list(Wtaunu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_500_1000[list(Wtaunu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_500_1000.keys()))), list(Wmunu_500_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)



###############################################################################################
# pt 1000+ GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_1000[list(Wmunu_1000.keys())[i]]["R_MC"])
    yerr.append(Wmunu_1000[list(Wmunu_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_1000[list(Wenu_1000.keys())[i]]["R_MC"]
    yerr[i] = Wenu_1000[list(Wenu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_1000[list(Wtaunu_1000.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_1000[list(Wtaunu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_1000.keys()))), list(Wmunu_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)
# Out:
# Text(0.5, 1.0, 'pt 1000+ GeV')

# %% [markdown]
# ## Non pesati

# %%
with open("Wjets/slice/R_non_pesati/Wmunu_0_70.txt", "r") as f:
    Wmunu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_0_70.txt", "r") as f:
    Wenu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_0_70.txt", "r") as f:
    Wtaunu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wmunu_70_140.txt", "r") as f:
    Wmunu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_70_140.txt", "r") as f:
    Wenu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_70_140.txt", "r") as f:
    Wtaunu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wmunu_140_280.txt", "r") as f:
    Wmunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_140_280.txt", "r") as f:
    Wenu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_140_280.txt", "r") as f:
    Wtaunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wmunu_280_500.txt", "r") as f:
    Wmunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_280_500.txt", "r") as f:
    Wenu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_280_500.txt", "r") as f:
    Wtaunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wmunu_500_1000.txt", "r") as f:
    Wmunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_500_1000.txt", "r") as f:
    Wenu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_500_1000.txt", "r") as f:
    Wtaunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wmunu_1000.txt", "r") as f:
    Wmunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Wjets/slice/R_non_pesati/Wenu_1000.txt", "r") as f:
    Wenu_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Wjets/slice/R_non_pesati/Wtaunu_1000.txt", "r") as f:
    Wtaunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

# %%
# pt 0_70 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_0_70[list(Wmunu_0_70.keys())[i]]["R_MC"])
    yerr.append(Wmunu_0_70[list(Wmunu_0_70.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_0_70[list(Wenu_0_70.keys())[i]]["R_MC"]
    yerr[i] = Wenu_0_70[list(Wenu_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_0_70[list(Wtaunu_0_70.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_0_70[list(Wtaunu_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 


#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_0_70.keys()))), list(Wmunu_0_70.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)



###############################################################################################
# pt 70 - 140 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_70_140[list(Wmunu_70_140.keys())[i]]["R_MC"])
    yerr.append(Wmunu_70_140[list(Wmunu_70_140.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_70_140[list(Wenu_70_140.keys())[i]]["R_MC"]
    yerr[i] = Wenu_70_140[list(Wenu_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_70_140[list(Wtaunu_70_140.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_70_140[list(Wtaunu_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_70_140.keys()))), list(Wmunu_70_140.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)



###############################################################################################
# pt 140 - 280 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_140_280[list(Wmunu_140_280.keys())[i]]["R_MC"])
    yerr.append(Wmunu_140_280[list(Wmunu_140_280.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_140_280[list(Wenu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Wenu_140_280[list(Wenu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_140_280[list(Wtaunu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_140_280[list(Wtaunu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_140_280.keys()))), list(Wmunu_140_280.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


###############################################################################################
# pt 280 - 500 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_280_500[list(Wmunu_280_500.keys())[i]]["R_MC"])
    yerr.append(Wmunu_280_500[list(Wmunu_280_500.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_280_500[list(Wenu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Wenu_280_500[list(Wenu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_280_500[list(Wtaunu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_280_500[list(Wtaunu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_280_500.keys()))), list(Wmunu_280_500.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)



###############################################################################################
# pt 500 - 1000 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_500_1000[list(Wmunu_500_1000.keys())[i]]["R_MC"])
    yerr.append(Wmunu_500_1000[list(Wmunu_500_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_500_1000[list(Wenu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Wenu_500_1000[list(Wenu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_500_1000[list(Wtaunu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_500_1000[list(Wtaunu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_500_1000.keys()))), list(Wmunu_500_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)



###############################################################################################
# pt 1000+ GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Wmunu
for i in range(21):
    x.append(i)
    y.append(Wmunu_1000[list(Wmunu_1000.keys())[i]]["R_MC"])
    yerr.append(Wmunu_1000[list(Wmunu_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Wmunu")
    
# Wenu
for i in range(21):
    y[i] = Wenu_1000[list(Wenu_1000.keys())[i]]["R_MC"]
    yerr[i] = Wenu_1000[list(Wenu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Wenu") 

# Wtaunu
for i in range(21):
    y[i] = Wtaunu_1000[list(Wtaunu_1000.keys())[i]]["R_MC"]
    yerr[i] = Wtaunu_1000[list(Wtaunu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Wtaunu") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Wmunu_1000.keys()))), list(Wmunu_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)
# Out:
# Text(0.5, 1.0, 'pt 1000+ GeV')

# %% [markdown]
# # Zjets

# %% [markdown]
# ## Pesati

# %%
with open("Zjets/slice/R_pesati/Zmumu_0_70.txt", "r") as f:
    Zmumu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_0_70.txt", "r") as f:
    Zee_0_70 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_0_70.txt", "r") as f:
    Ztautau_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zmumu_70_140.txt", "r") as f:
    Zmumu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_70_140.txt", "r") as f:
    Zee_70_140 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_70_140.txt", "r") as f:
    Ztautau_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zmumu_140_280.txt", "r") as f:
    Zmumu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_140_280.txt", "r") as f:
    Zee_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_140_280.txt", "r") as f:
    Ztautau_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Znunu_140_280.txt", "r") as f:
    Znunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zmumu_280_500.txt", "r") as f:
    Zmumu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_280_500.txt", "r") as f:
    Zee_280_500 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_280_500.txt", "r") as f:
    Ztautau_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Znunu_280_500.txt", "r") as f:
    Znunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zmumu_500_1000.txt", "r") as f:
    Zmumu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_500_1000.txt", "r") as f:
    Zee_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_500_1000.txt", "r") as f:
    Ztautau_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Znunu_500_1000.txt", "r") as f:
    Znunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zmumu_1000.txt", "r") as f:
    Zmumu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Zee_1000.txt", "r") as f:
    Zee_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_pesati/Ztautau_1000.txt", "r") as f:
    Ztautau_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_pesati/Znunu_1000.txt", "r") as f:
    Znunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

# %%
# pt 0_70 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_0_70[list(Zmumu_0_70.keys())[i]]["R_MC"])
    yerr.append(Zmumu_0_70[list(Zmumu_0_70.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_0_70[list(Zee_0_70.keys())[i]]["R_MC"]
    yerr[i] = Zee_0_70[list(Zee_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_0_70[list(Ztautau_0_70.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_0_70[list(Ztautau_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Znunu") 


#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_0_70.keys()))), list(Zmumu_0_70.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)



###############################################################################################
# pt 70 - 140 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_70_140[list(Zmumu_70_140.keys())[i]]["R_MC"])
    yerr.append(Zmumu_70_140[list(Zmumu_70_140.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_70_140[list(Zee_70_140.keys())[i]]["R_MC"]
    yerr[i] = Zee_70_140[list(Zee_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_70_140[list(Ztautau_70_140.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_70_140[list(Ztautau_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_70_140.keys()))), list(Zmumu_70_140.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)



###############################################################################################
# pt 140 - 280 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_140_280[list(Zmumu_140_280.keys())[i]]["R_MC"])
    yerr.append(Zmumu_140_280[list(Zmumu_140_280.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_140_280[list(Zee_140_280.keys())[i]]["R_MC"]
    yerr[i] = Zee_140_280[list(Zee_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_140_280[list(Ztautau_140_280.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_140_280[list(Ztautau_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_140_280[list(Znunu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Znunu_140_280[list(Znunu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 


    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_140_280.keys()))), list(Zmumu_140_280.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


###############################################################################################
# pt 280 - 500 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_280_500[list(Zmumu_280_500.keys())[i]]["R_MC"])
    yerr.append(Zmumu_280_500[list(Zmumu_280_500.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_280_500[list(Zee_280_500.keys())[i]]["R_MC"]
    yerr[i] = Zee_280_500[list(Zee_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_280_500[list(Ztautau_280_500.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_280_500[list(Ztautau_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau")

# Znunu
for i in range(21):
    y[i] = Znunu_280_500[list(Znunu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Znunu_280_500[list(Znunu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu")



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_280_500.keys()))), list(Zmumu_280_500.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)



###############################################################################################
# pt 500 - 1000 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_500_1000[list(Zmumu_500_1000.keys())[i]]["R_MC"])
    yerr.append(Zmumu_500_1000[list(Zmumu_500_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_500_1000[list(Zee_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Zee_500_1000[list(Zee_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_500_1000[list(Ztautau_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_500_1000[list(Ztautau_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_500_1000[list(Znunu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Znunu_500_1000[list(Znunu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 




    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_500_1000.keys()))), list(Zmumu_500_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)



###############################################################################################
# pt 1000+ GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_1000[list(Zmumu_1000.keys())[i]]["R_MC"])
    yerr.append(Zmumu_1000[list(Zmumu_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_1000[list(Zee_1000.keys())[i]]["R_MC"]
    yerr[i] = Zee_1000[list(Zee_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_1000[list(Ztautau_1000.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_1000[list(Ztautau_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_1000[list(Znunu_1000.keys())[i]]["R_MC"]
    yerr[i] = Znunu_1000[list(Znunu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 

    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_1000.keys()))), list(Zmumu_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)
# Out:
# Text(0.5, 1.0, 'pt 1000+ GeV')

# %% [markdown]
# ## Non pesati

# %%
with open("Zjets/slice/R_non_pesati/Zmumu_0_70.txt", "r") as f:
    Zmumu_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_0_70.txt", "r") as f:
    Zee_0_70 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_0_70.txt", "r") as f:
    Ztautau_0_70 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zmumu_70_140.txt", "r") as f:
    Zmumu_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_70_140.txt", "r") as f:
    Zee_70_140 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_70_140.txt", "r") as f:
    Ztautau_70_140 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zmumu_140_280.txt", "r") as f:
    Zmumu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_140_280.txt", "r") as f:
    Zee_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_140_280.txt", "r") as f:
    Ztautau_140_280 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Znunu_140_280.txt", "r") as f:
    Znunu_140_280 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zmumu_280_500.txt", "r") as f:
    Zmumu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_280_500.txt", "r") as f:
    Zee_280_500 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_280_500.txt", "r") as f:
    Ztautau_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Znunu_280_500.txt", "r") as f:
    Znunu_280_500 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zmumu_500_1000.txt", "r") as f:
    Zmumu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_500_1000.txt", "r") as f:
    Zee_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_500_1000.txt", "r") as f:
    Ztautau_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Znunu_500_1000.txt", "r") as f:
    Znunu_500_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Zmumu_1000.txt", "r") as f:
    Zmumu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Zee_1000.txt", "r") as f:
    Zee_1000 = yaml.load(f, Loader=yaml.SafeLoader)
    
with open("Zjets/slice/R_non_pesati/Ztautau_1000.txt", "r") as f:
    Ztautau_1000 = yaml.load(f, Loader=yaml.SafeLoader)

with open("Zjets/slice/R_non_pesati/Znunu_1000.txt", "r") as f:
    Znunu_1000 = yaml.load(f, Loader=yaml.SafeLoader)

# %%
# pt 0_70 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_0_70[list(Zmumu_0_70.keys())[i]]["R_MC"])
    yerr.append(Zmumu_0_70[list(Zmumu_0_70.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_0_70[list(Zee_0_70.keys())[i]]["R_MC"]
    yerr[i] = Zee_0_70[list(Zee_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_0_70[list(Ztautau_0_70.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_0_70[list(Ztautau_0_70.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Znunu") 


#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_0_70.keys()))), list(Zmumu_0_70.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)



###############################################################################################
# pt 70 - 140 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_70_140[list(Zmumu_70_140.keys())[i]]["R_MC"])
    yerr.append(Zmumu_70_140[list(Zmumu_70_140.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_70_140[list(Zee_70_140.keys())[i]]["R_MC"]
    yerr[i] = Zee_70_140[list(Zee_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_70_140[list(Ztautau_70_140.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_70_140[list(Ztautau_70_140.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_70_140.keys()))), list(Zmumu_70_140.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)



###############################################################################################
# pt 140 - 280 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_140_280[list(Zmumu_140_280.keys())[i]]["R_MC"])
    yerr.append(Zmumu_140_280[list(Zmumu_140_280.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_140_280[list(Zee_140_280.keys())[i]]["R_MC"]
    yerr[i] = Zee_140_280[list(Zee_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_140_280[list(Ztautau_140_280.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_140_280[list(Ztautau_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_140_280[list(Znunu_140_280.keys())[i]]["R_MC"]
    yerr[i] = Znunu_140_280[list(Znunu_140_280.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 


    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_140_280.keys()))), list(Zmumu_140_280.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


###############################################################################################
# pt 280 - 500 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_280_500[list(Zmumu_280_500.keys())[i]]["R_MC"])
    yerr.append(Zmumu_280_500[list(Zmumu_280_500.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_280_500[list(Zee_280_500.keys())[i]]["R_MC"]
    yerr[i] = Zee_280_500[list(Zee_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_280_500[list(Ztautau_280_500.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_280_500[list(Ztautau_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau")

# Znunu
for i in range(21):
    y[i] = Znunu_280_500[list(Znunu_280_500.keys())[i]]["R_MC"]
    yerr[i] = Znunu_280_500[list(Znunu_280_500.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu")



    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_280_500.keys()))), list(Zmumu_280_500.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)



###############################################################################################
# pt 500 - 1000 GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_500_1000[list(Zmumu_500_1000.keys())[i]]["R_MC"])
    yerr.append(Zmumu_500_1000[list(Zmumu_500_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_500_1000[list(Zee_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Zee_500_1000[list(Zee_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_500_1000[list(Ztautau_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_500_1000[list(Ztautau_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_500_1000[list(Znunu_500_1000.keys())[i]]["R_MC"]
    yerr[i] = Znunu_500_1000[list(Znunu_500_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 




    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_500_1000.keys()))), list(Zmumu_500_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)



###############################################################################################
# pt 1000+ GeV

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

x = []
y = []
yerr = []

# Zmumu
for i in range(21):
    x.append(i)
    y.append(Zmumu_1000[list(Zmumu_1000.keys())[i]]["R_MC"])
    yerr.append(Zmumu_1000[list(Zmumu_1000.keys())[i]]["sigma_R_MC"])

plt.errorbar(x, y, yerr=None, fmt="ob", linestyle="-", linewidth=2, label="Zmumu")
    
# Zee
for i in range(21):
    y[i] = Zee_1000[list(Zee_1000.keys())[i]]["R_MC"]
    yerr[i] = Zee_1000[list(Zee_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="or", linestyle="-", linewidth=2, label="Zee") 

# Ztautau
for i in range(21):
    y[i] = Ztautau_1000[list(Ztautau_1000.keys())[i]]["R_MC"]
    yerr[i] = Ztautau_1000[list(Ztautau_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="og", linestyle="-", linewidth=2, label="Ztautau") 

# Znunu
for i in range(21):
    y[i] = Znunu_1000[list(Znunu_1000.keys())[i]]["R_MC"]
    yerr[i] = Znunu_1000[list(Znunu_1000.keys())[i]]["sigma_R_MC"]

plt.errorbar(x, y, yerr=None, fmt="oy", linestyle="-", linewidth=2, label="Znunu") 

    
#plt.axis([-1, 21, -3, 3])
plt.xticks(range(len(list(Zmumu_1000.keys()))), list(Zmumu_1000.keys()))
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)
# Out:
# Text(0.5, 1.0, 'pt 1000+ GeV')

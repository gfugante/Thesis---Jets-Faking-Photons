# %%
import yaml
import matplotlib.pyplot as plt
from os import listdir
import math
#import pandas as pd

# %% [markdown]
# # Wjets

# %% [markdown]
# ## Non pesati

# %%
# carico i file in data

PATH = "Wjets/slice_notrack/R_non_pesati"
keys = sorted(listdir(PATH))
for i in range(len(keys)):
    keys[i] = keys[i].split(".")[0]


values = []
for i in range(len(keys)):
    with open(PATH+"/"+keys[i]+".txt", "r") as f:
        values.append(yaml.load(f, Loader=yaml.SafeLoader))


regions = list(values[0].keys())
data = dict(zip(keys, values))

x = [i for i in range(21)]



# pt 0-70 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364156"][regions[i]]["Na_b"] +
      data["364170"][regions[i]]["Na_b"] +
      data["364184"][regions[i]]["Na_b"] +
      data["364157"][regions[i]]["Na_b"] +
      data["364171"][regions[i]]["Na_b"] +
      data["364185"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364156"][regions[i]]["Nb_b"] +
      data["364170"][regions[i]]["Nb_b"] +
      data["364184"][regions[i]]["Nb_b"] +
      data["364157"][regions[i]]["Nb_b"] +
      data["364171"][regions[i]]["Nb_b"] +
      data["364185"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364156"][regions[i]]["Ma_b"] +
      data["364170"][regions[i]]["Ma_b"] +
      data["364184"][regions[i]]["Ma_b"] +
      data["364157"][regions[i]]["Ma_b"] +
      data["364171"][regions[i]]["Ma_b"] +
      data["364185"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364156"][regions[i]]["Mb_b"] +
      data["364170"][regions[i]]["Mb_b"] +
      data["364184"][regions[i]]["Mb_b"] +
      data["364157"][regions[i]]["Mb_b"] +
      data["364171"][regions[i]]["Mb_b"] +
      data["364185"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 0 - 70 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)


# pt 70-140 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364159"][regions[i]]["Na_b"] +
      data["364173"][regions[i]]["Na_b"] +
      data["364187"][regions[i]]["Na_b"] +
      data["364160"][regions[i]]["Na_b"] +
      data["364174"][regions[i]]["Na_b"] +
      data["364188"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364159"][regions[i]]["Nb_b"] +
      data["364173"][regions[i]]["Nb_b"] +
      data["364187"][regions[i]]["Nb_b"] +
      data["364160"][regions[i]]["Nb_b"] +
      data["364174"][regions[i]]["Nb_b"] +
      data["364188"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364159"][regions[i]]["Ma_b"] +
      data["364173"][regions[i]]["Ma_b"] +
      data["364187"][regions[i]]["Ma_b"] +
      data["364160"][regions[i]]["Ma_b"] +
      data["364174"][regions[i]]["Ma_b"] +
      data["364188"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364159"][regions[i]]["Mb_b"] +
      data["364173"][regions[i]]["Mb_b"] +
      data["364187"][regions[i]]["Mb_b"] +
      data["364160"][regions[i]]["Mb_b"] +
      data["364174"][regions[i]]["Mb_b"] +
      data["364188"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 70 - 140 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 140-280 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364162"][regions[i]]["Na_b"] +
      data["364176"][regions[i]]["Na_b"] +
      data["364190"][regions[i]]["Na_b"] +
      data["364163"][regions[i]]["Na_b"] +
      data["364177"][regions[i]]["Na_b"] +
      data["364191"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364162"][regions[i]]["Nb_b"] +
      data["364176"][regions[i]]["Nb_b"] +
      data["364190"][regions[i]]["Nb_b"] +
      data["364163"][regions[i]]["Nb_b"] +
      data["364177"][regions[i]]["Nb_b"] +
      data["364191"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364162"][regions[i]]["Ma_b"] +
      data["364176"][regions[i]]["Ma_b"] +
      data["364190"][regions[i]]["Ma_b"] +
      data["364163"][regions[i]]["Ma_b"] +
      data["364177"][regions[i]]["Ma_b"] +
      data["364191"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364162"][regions[i]]["Mb_b"] +
      data["364176"][regions[i]]["Mb_b"] +
      data["364190"][regions[i]]["Mb_b"] +
      data["364163"][regions[i]]["Mb_b"] +
      data["364177"][regions[i]]["Mb_b"] +
      data["364191"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 140 - 280 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 280-500 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364165"][regions[i]]["Na_b"] +
      data["364179"][regions[i]]["Na_b"] +
      data["364193"][regions[i]]["Na_b"] +
      data["364166"][regions[i]]["Na_b"] +
      data["364180"][regions[i]]["Na_b"] +
      data["364194"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364165"][regions[i]]["Nb_b"] +
      data["364179"][regions[i]]["Nb_b"] +
      data["364193"][regions[i]]["Nb_b"] +
      data["364166"][regions[i]]["Nb_b"] +
      data["364180"][regions[i]]["Nb_b"] +
      data["364194"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364165"][regions[i]]["Ma_b"] +
      data["364179"][regions[i]]["Ma_b"] +
      data["364193"][regions[i]]["Ma_b"] +
      data["364166"][regions[i]]["Ma_b"] +
      data["364180"][regions[i]]["Ma_b"] +
      data["364194"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364165"][regions[i]]["Mb_b"] +
      data["364179"][regions[i]]["Mb_b"] +
      data["364193"][regions[i]]["Mb_b"] +
      data["364166"][regions[i]]["Mb_b"] +
      data["364180"][regions[i]]["Mb_b"] +
      data["364194"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 280 - 500 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 500-1000 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364168"][regions[i]]["Na_b"] +
      data["364182"][regions[i]]["Na_b"] +
      data["364196"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364168"][regions[i]]["Nb_b"] +
      data["364182"][regions[i]]["Nb_b"] +
      data["364196"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364168"][regions[i]]["Ma_b"] +
      data["364182"][regions[i]]["Ma_b"] +
      data["364196"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364168"][regions[i]]["Mb_b"] +
      data["364182"][regions[i]]["Mb_b"] +
      data["364196"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 500 - 1000 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)




# pt 1000+ GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364169"][regions[i]]["Na_b"] +
      data["364183"][regions[i]]["Na_b"] +
      data["364197"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364169"][regions[i]]["Nb_b"] +
      data["364183"][regions[i]]["Nb_b"] +
      data["364197"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364169"][regions[i]]["Ma_b"] +
      data["364183"][regions[i]]["Ma_b"] +
      data["364197"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364169"][regions[i]]["Mb_b"] +
      data["364183"][regions[i]]["Mb_b"] +
      data["364197"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 1000+ GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)

# %% [markdown]
# ## Pesati

# %%
# carico i file in data

PATH = "Wjets/slice_notrack/R_pesati"
keys = sorted(listdir(PATH))
for i in range(len(keys)):
    keys[i] = keys[i].split(".")[0]


values = []
for i in range(len(keys)):
    with open(PATH+"/"+keys[i]+".txt", "r") as f:
        values.append(yaml.load(f, Loader=yaml.SafeLoader))


regions = list(values[0].keys())
data = dict(zip(keys, values))

x = [i for i in range(21)]



# pt 0-70 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364156"][regions[i]]["Na_b"] +
      data["364170"][regions[i]]["Na_b"] +
      data["364184"][regions[i]]["Na_b"] +
      data["364157"][regions[i]]["Na_b"] +
      data["364171"][regions[i]]["Na_b"] +
      data["364185"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364156"][regions[i]]["Nb_b"] +
      data["364170"][regions[i]]["Nb_b"] +
      data["364184"][regions[i]]["Nb_b"] +
      data["364157"][regions[i]]["Nb_b"] +
      data["364171"][regions[i]]["Nb_b"] +
      data["364185"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364156"][regions[i]]["Ma_b"] +
      data["364170"][regions[i]]["Ma_b"] +
      data["364184"][regions[i]]["Ma_b"] +
      data["364157"][regions[i]]["Ma_b"] +
      data["364171"][regions[i]]["Ma_b"] +
      data["364185"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364156"][regions[i]]["Mb_b"] +
      data["364170"][regions[i]]["Mb_b"] +
      data["364184"][regions[i]]["Mb_b"] +
      data["364157"][regions[i]]["Mb_b"] +
      data["364171"][regions[i]]["Mb_b"] +
      data["364185"][regions[i]]["Mb_b"]
      for i in range(21)]


plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 0 - 70 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)


# pt 70-140 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364159"][regions[i]]["Na_b"] +
      data["364173"][regions[i]]["Na_b"] +
      data["364187"][regions[i]]["Na_b"] +
      data["364160"][regions[i]]["Na_b"] +
      data["364174"][regions[i]]["Na_b"] +
      data["364188"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364159"][regions[i]]["Nb_b"] +
      data["364173"][regions[i]]["Nb_b"] +
      data["364187"][regions[i]]["Nb_b"] +
      data["364160"][regions[i]]["Nb_b"] +
      data["364174"][regions[i]]["Nb_b"] +
      data["364188"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364159"][regions[i]]["Ma_b"] +
      data["364173"][regions[i]]["Ma_b"] +
      data["364187"][regions[i]]["Ma_b"] +
      data["364160"][regions[i]]["Ma_b"] +
      data["364174"][regions[i]]["Ma_b"] +
      data["364188"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364159"][regions[i]]["Mb_b"] +
      data["364173"][regions[i]]["Mb_b"] +
      data["364187"][regions[i]]["Mb_b"] +
      data["364160"][regions[i]]["Mb_b"] +
      data["364174"][regions[i]]["Mb_b"] +
      data["364188"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 70 - 140 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 140-280 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364162"][regions[i]]["Na_b"] +
      data["364176"][regions[i]]["Na_b"] +
      data["364190"][regions[i]]["Na_b"] +
      data["364163"][regions[i]]["Na_b"] +
      data["364177"][regions[i]]["Na_b"] +
      data["364191"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364162"][regions[i]]["Nb_b"] +
      data["364176"][regions[i]]["Nb_b"] +
      data["364190"][regions[i]]["Nb_b"] +
      data["364163"][regions[i]]["Nb_b"] +
      data["364177"][regions[i]]["Nb_b"] +
      data["364191"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364162"][regions[i]]["Ma_b"] +
      data["364176"][regions[i]]["Ma_b"] +
      data["364190"][regions[i]]["Ma_b"] +
      data["364163"][regions[i]]["Ma_b"] +
      data["364177"][regions[i]]["Ma_b"] +
      data["364191"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364162"][regions[i]]["Mb_b"] +
      data["364176"][regions[i]]["Mb_b"] +
      data["364190"][regions[i]]["Mb_b"] +
      data["364163"][regions[i]]["Mb_b"] +
      data["364177"][regions[i]]["Mb_b"] +
      data["364191"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 140 - 280 GeV", fontsize=30)
#plt.axis([-1, 21, 0, 3])

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 280-500 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364165"][regions[i]]["Na_b"] +
      data["364179"][regions[i]]["Na_b"] +
      data["364193"][regions[i]]["Na_b"] +
      data["364166"][regions[i]]["Na_b"] +
      data["364180"][regions[i]]["Na_b"] +
      data["364194"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364165"][regions[i]]["Nb_b"] +
      data["364179"][regions[i]]["Nb_b"] +
      data["364193"][regions[i]]["Nb_b"] +
      data["364166"][regions[i]]["Nb_b"] +
      data["364180"][regions[i]]["Nb_b"] +
      data["364194"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364165"][regions[i]]["Ma_b"] +
      data["364179"][regions[i]]["Ma_b"] +
      data["364193"][regions[i]]["Ma_b"] +
      data["364166"][regions[i]]["Ma_b"] +
      data["364180"][regions[i]]["Ma_b"] +
      data["364194"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364165"][regions[i]]["Mb_b"] +
      data["364179"][regions[i]]["Mb_b"] +
      data["364193"][regions[i]]["Mb_b"] +
      data["364166"][regions[i]]["Mb_b"] +
      data["364180"][regions[i]]["Mb_b"] +
      data["364194"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 280 - 500 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 500-1000 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364168"][regions[i]]["Na_b"] +
      data["364182"][regions[i]]["Na_b"] +
      data["364196"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364168"][regions[i]]["Nb_b"] +
      data["364182"][regions[i]]["Nb_b"] +
      data["364196"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364168"][regions[i]]["Ma_b"] +
      data["364182"][regions[i]]["Ma_b"] +
      data["364196"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364168"][regions[i]]["Mb_b"] +
      data["364182"][regions[i]]["Mb_b"] +
      data["364196"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 500 - 1000 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)




# pt 1000+ GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364169"][regions[i]]["Na_b"] +
      data["364183"][regions[i]]["Na_b"] +
      data["364197"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364169"][regions[i]]["Nb_b"] +
      data["364183"][regions[i]]["Nb_b"] +
      data["364197"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364169"][regions[i]]["Ma_b"] +
      data["364183"][regions[i]]["Ma_b"] +
      data["364197"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364169"][regions[i]]["Mb_b"] +
      data["364183"][regions[i]]["Mb_b"] +
      data["364197"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError,ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 1000+ GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)

# %% [markdown]
# # Zjets

# %% [markdown]
# ## Non pesati

# %%
# carico i file in data

PATH = "Zjets/slice_notrack/R_non_pesati"
keys = sorted(listdir(PATH))
for i in range(len(keys)):
    keys[i] = keys[i].split(".")[0]


values = []
for i in range(len(keys)):
    with open(PATH+"/"+keys[i]+".txt", "r") as f:
        values.append(yaml.load(f, Loader=yaml.SafeLoader))


regions = list(values[0].keys())
data = dict(zip(keys, values))

x = [i for i in range(21)]



# pt 0-70 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364100"][regions[i]]["Na_b"] +
      data["364114"][regions[i]]["Na_b"] +
      data["364128"][regions[i]]["Na_b"] +
      data["364101"][regions[i]]["Na_b"] +
      data["364115"][regions[i]]["Na_b"] +
      data["364129"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364100"][regions[i]]["Nb_b"] +
      data["364114"][regions[i]]["Nb_b"] +
      data["364128"][regions[i]]["Nb_b"] +
      data["364101"][regions[i]]["Nb_b"] +
      data["364115"][regions[i]]["Nb_b"] +
      data["364129"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364100"][regions[i]]["Ma_b"] +
      data["364114"][regions[i]]["Ma_b"] +
      data["364128"][regions[i]]["Ma_b"] +
      data["364101"][regions[i]]["Ma_b"] +
      data["364115"][regions[i]]["Ma_b"] +
      data["364129"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364100"][regions[i]]["Mb_b"] +
      data["364114"][regions[i]]["Mb_b"] +
      data["364128"][regions[i]]["Mb_b"] +
      data["364101"][regions[i]]["Mb_b"] +
      data["364115"][regions[i]]["Mb_b"] +
      data["364129"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 0 - 70 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 70-140 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364103"][regions[i]]["Na_b"] +
      data["364117"][regions[i]]["Na_b"] +
      data["364131"][regions[i]]["Na_b"] +
      data["364104"][regions[i]]["Na_b"] +
      data["364118"][regions[i]]["Na_b"] +
      data["364132"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364103"][regions[i]]["Nb_b"] +
      data["364117"][regions[i]]["Nb_b"] +
      data["364131"][regions[i]]["Nb_b"] +
      data["364104"][regions[i]]["Nb_b"] +
      data["364118"][regions[i]]["Nb_b"] +
      data["364132"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364103"][regions[i]]["Ma_b"] +
      data["364117"][regions[i]]["Ma_b"] +
      data["364131"][regions[i]]["Ma_b"] +
      data["364104"][regions[i]]["Ma_b"] +
      data["364118"][regions[i]]["Ma_b"] +
      data["364132"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364103"][regions[i]]["Mb_b"] +
      data["364117"][regions[i]]["Mb_b"] +
      data["364131"][regions[i]]["Mb_b"] +
      data["364104"][regions[i]]["Mb_b"] +
      data["364118"][regions[i]]["Mb_b"] +
      data["364132"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 70 - 140 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 140-280 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364106"][regions[i]]["Na_b"] +
      data["364120"][regions[i]]["Na_b"] +
      data["364134"][regions[i]]["Na_b"] +
      data["364107"][regions[i]]["Na_b"] +
      data["364121"][regions[i]]["Na_b"] +
      data["364135"][regions[i]]["Na_b"] +
      data["364148"][regions[i]]["Na_b"] +
      data["364149"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364106"][regions[i]]["Nb_b"] +
      data["364120"][regions[i]]["Nb_b"] +
      data["364134"][regions[i]]["Nb_b"] +
      data["364107"][regions[i]]["Nb_b"] +
      data["364121"][regions[i]]["Nb_b"] +
      data["364135"][regions[i]]["Nb_b"] +
      data["364148"][regions[i]]["Nb_b"] +
      data["364149"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364106"][regions[i]]["Ma_b"] +
      data["364120"][regions[i]]["Ma_b"] +
      data["364134"][regions[i]]["Ma_b"] +
      data["364107"][regions[i]]["Ma_b"] +
      data["364121"][regions[i]]["Ma_b"] +
      data["364135"][regions[i]]["Ma_b"] +
      data["364148"][regions[i]]["Ma_b"] +
      data["364149"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364106"][regions[i]]["Mb_b"] +
      data["364120"][regions[i]]["Mb_b"] +
      data["364134"][regions[i]]["Mb_b"] +
      data["364107"][regions[i]]["Mb_b"] +
      data["364121"][regions[i]]["Mb_b"] +
      data["364135"][regions[i]]["Mb_b"] +
      data["364148"][regions[i]]["Mb_b"] +
      data["364149"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 140 - 280 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 280-500 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364109"][regions[i]]["Na_b"] +
      data["364122"][regions[i]]["Na_b"] +
      data["364137"][regions[i]]["Na_b"] +
      data["364110"][regions[i]]["Na_b"] +
      data["364123"][regions[i]]["Na_b"] +
      data["364138"][regions[i]]["Na_b"] +
      data["364151"][regions[i]]["Na_b"] +
      data["364152"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364109"][regions[i]]["Nb_b"] +
      data["364122"][regions[i]]["Nb_b"] +
      data["364137"][regions[i]]["Nb_b"] +
      data["364110"][regions[i]]["Nb_b"] +
      data["364123"][regions[i]]["Nb_b"] +
      data["364138"][regions[i]]["Nb_b"] +
      data["364151"][regions[i]]["Nb_b"] +
      data["364152"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364109"][regions[i]]["Ma_b"] +
      data["364122"][regions[i]]["Ma_b"] +
      data["364137"][regions[i]]["Ma_b"] +
      data["364110"][regions[i]]["Ma_b"] +
      data["364123"][regions[i]]["Ma_b"] +
      data["364138"][regions[i]]["Ma_b"] +
      data["364151"][regions[i]]["Ma_b"] +
      data["364152"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364109"][regions[i]]["Mb_b"] +
      data["364122"][regions[i]]["Mb_b"] +
      data["364137"][regions[i]]["Mb_b"] +
      data["364110"][regions[i]]["Mb_b"] +
      data["364123"][regions[i]]["Mb_b"] +
      data["364138"][regions[i]]["Mb_b"] +
      data["364151"][regions[i]]["Mb_b"] +
      data["364152"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 280 - 500 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 500-1000 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364112"][regions[i]]["Na_b"] +
      data["364126"][regions[i]]["Na_b"] +
      data["364140"][regions[i]]["Na_b"] +
      data["364154"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364112"][regions[i]]["Nb_b"] +
      data["364126"][regions[i]]["Nb_b"] +
      data["364140"][regions[i]]["Nb_b"] +
      data["364154"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364112"][regions[i]]["Ma_b"] +
      data["364126"][regions[i]]["Ma_b"] +
      data["364140"][regions[i]]["Ma_b"] +
      data["364154"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364112"][regions[i]]["Mb_b"] +
      data["364126"][regions[i]]["Mb_b"] +
      data["364140"][regions[i]]["Mb_b"] +
      data["364154"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 500 - 1000 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)




# pt 1000+ GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364113"][regions[i]]["Na_b"] +
      data["364127"][regions[i]]["Na_b"] +
      data["364141"][regions[i]]["Na_b"] +
      data["364155"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364113"][regions[i]]["Nb_b"] +
      data["364127"][regions[i]]["Nb_b"] +
      data["364141"][regions[i]]["Nb_b"] +
      data["364155"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364113"][regions[i]]["Ma_b"] +
      data["364127"][regions[i]]["Ma_b"] +
      data["364141"][regions[i]]["Ma_b"] +
      data["364155"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364113"][regions[i]]["Mb_b"] +
      data["364127"][regions[i]]["Mb_b"] +
      data["364141"][regions[i]]["Mb_b"] +
      data["364155"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except ZeroDivisionError:
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 1000+ GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)

# %% [markdown]
# ## Pesati

# %%
# carico i file in data

PATH = "Zjets/slice_notrack/R_pesati"
keys = sorted(listdir(PATH))
for i in range(len(keys)):
    keys[i] = keys[i].split(".")[0]


values = []
for i in range(len(keys)):
    with open(PATH+"/"+keys[i]+".txt", "r") as f:
        values.append(yaml.load(f, Loader=yaml.SafeLoader))


regions = list(values[0].keys())
data = dict(zip(keys, values))

x = [i for i in range(21)]



# pt 0-70 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364100"][regions[i]]["Na_b"] +
      data["364114"][regions[i]]["Na_b"] +
      data["364128"][regions[i]]["Na_b"] +
      data["364101"][regions[i]]["Na_b"] +
      data["364115"][regions[i]]["Na_b"] +
      data["364129"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364100"][regions[i]]["Nb_b"] +
      data["364114"][regions[i]]["Nb_b"] +
      data["364128"][regions[i]]["Nb_b"] +
      data["364101"][regions[i]]["Nb_b"] +
      data["364115"][regions[i]]["Nb_b"] +
      data["364129"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364100"][regions[i]]["Ma_b"] +
      data["364114"][regions[i]]["Ma_b"] +
      data["364128"][regions[i]]["Ma_b"] +
      data["364101"][regions[i]]["Ma_b"] +
      data["364115"][regions[i]]["Ma_b"] +
      data["364129"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364100"][regions[i]]["Mb_b"] +
      data["364114"][regions[i]]["Mb_b"] +
      data["364128"][regions[i]]["Mb_b"] +
      data["364101"][regions[i]]["Mb_b"] +
      data["364115"][regions[i]]["Mb_b"] +
      data["364129"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 0 - 70 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 0 - 70 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)


# pt 70-140 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364103"][regions[i]]["Na_b"] +
      data["364117"][regions[i]]["Na_b"] +
      data["364131"][regions[i]]["Na_b"] +
      data["364104"][regions[i]]["Na_b"] +
      data["364118"][regions[i]]["Na_b"] +
      data["364132"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364103"][regions[i]]["Nb_b"] +
      data["364117"][regions[i]]["Nb_b"] +
      data["364131"][regions[i]]["Nb_b"] +
      data["364104"][regions[i]]["Nb_b"] +
      data["364118"][regions[i]]["Nb_b"] +
      data["364132"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364103"][regions[i]]["Ma_b"] +
      data["364117"][regions[i]]["Ma_b"] +
      data["364131"][regions[i]]["Ma_b"] +
      data["364104"][regions[i]]["Ma_b"] +
      data["364118"][regions[i]]["Ma_b"] +
      data["364132"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364103"][regions[i]]["Mb_b"] +
      data["364117"][regions[i]]["Mb_b"] +
      data["364131"][regions[i]]["Mb_b"] +
      data["364104"][regions[i]]["Mb_b"] +
      data["364118"][regions[i]]["Mb_b"] +
      data["364132"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 70 - 140 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 70 - 140 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 140-280 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364106"][regions[i]]["Na_b"] +
      data["364120"][regions[i]]["Na_b"] +
      data["364134"][regions[i]]["Na_b"] +
      data["364107"][regions[i]]["Na_b"] +
      data["364121"][regions[i]]["Na_b"] +
      data["364135"][regions[i]]["Na_b"] +
      data["364148"][regions[i]]["Na_b"] +
      data["364149"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364106"][regions[i]]["Nb_b"] +
      data["364120"][regions[i]]["Nb_b"] +
      data["364134"][regions[i]]["Nb_b"] +
      data["364107"][regions[i]]["Nb_b"] +
      data["364121"][regions[i]]["Nb_b"] +
      data["364135"][regions[i]]["Nb_b"] +
      data["364148"][regions[i]]["Nb_b"] +
      data["364149"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364106"][regions[i]]["Ma_b"] +
      data["364120"][regions[i]]["Ma_b"] +
      data["364134"][regions[i]]["Ma_b"] +
      data["364107"][regions[i]]["Ma_b"] +
      data["364121"][regions[i]]["Ma_b"] +
      data["364135"][regions[i]]["Ma_b"] +
      data["364148"][regions[i]]["Ma_b"] +
      data["364149"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364106"][regions[i]]["Mb_b"] +
      data["364120"][regions[i]]["Mb_b"] +
      data["364134"][regions[i]]["Mb_b"] +
      data["364107"][regions[i]]["Mb_b"] +
      data["364121"][regions[i]]["Mb_b"] +
      data["364135"][regions[i]]["Mb_b"] +
      data["364148"][regions[i]]["Mb_b"] +
      data["364149"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 140 - 280 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 140 - 280 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)



# pt 280-500 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364109"][regions[i]]["Na_b"] +
      data["364122"][regions[i]]["Na_b"] +
      data["364137"][regions[i]]["Na_b"] +
      data["364110"][regions[i]]["Na_b"] +
      data["364123"][regions[i]]["Na_b"] +
      data["364138"][regions[i]]["Na_b"] +
      data["364151"][regions[i]]["Na_b"] +
      data["364152"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364109"][regions[i]]["Nb_b"] +
      data["364122"][regions[i]]["Nb_b"] +
      data["364137"][regions[i]]["Nb_b"] +
      data["364110"][regions[i]]["Nb_b"] +
      data["364123"][regions[i]]["Nb_b"] +
      data["364138"][regions[i]]["Nb_b"] +
      data["364151"][regions[i]]["Nb_b"] +
      data["364152"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364109"][regions[i]]["Ma_b"] +
      data["364122"][regions[i]]["Ma_b"] +
      data["364137"][regions[i]]["Ma_b"] +
      data["364110"][regions[i]]["Ma_b"] +
      data["364123"][regions[i]]["Ma_b"] +
      data["364138"][regions[i]]["Ma_b"] +
      data["364151"][regions[i]]["Ma_b"] +
      data["364152"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364109"][regions[i]]["Mb_b"] +
      data["364122"][regions[i]]["Mb_b"] +
      data["364137"][regions[i]]["Mb_b"] +
      data["364110"][regions[i]]["Mb_b"] +
      data["364123"][regions[i]]["Mb_b"] +
      data["364138"][regions[i]]["Mb_b"] +
      data["364151"][regions[i]]["Mb_b"] +
      data["364152"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 280 - 500 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
#sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 280 - 500 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)




# pt 500-1000 GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364112"][regions[i]]["Na_b"] +
      data["364126"][regions[i]]["Na_b"] +
      data["364140"][regions[i]]["Na_b"] +
      data["364154"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364112"][regions[i]]["Nb_b"] +
      data["364126"][regions[i]]["Nb_b"] +
      data["364140"][regions[i]]["Nb_b"] +
      data["364154"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364112"][regions[i]]["Ma_b"] +
      data["364126"][regions[i]]["Ma_b"] +
      data["364140"][regions[i]]["Ma_b"] +
      data["364154"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364112"][regions[i]]["Mb_b"] +
      data["364126"][regions[i]]["Mb_b"] +
      data["364140"][regions[i]]["Mb_b"] +
      data["364154"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 500 - 1000 GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 500 - 1000 GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)




# pt 1000+ GeV

# CVetoBVeto + CFilterBVeto

Na = [data["364113"][regions[i]]["Na_b"] +
      data["364127"][regions[i]]["Na_b"] +
      data["364141"][regions[i]]["Na_b"] +
      data["364155"][regions[i]]["Na_b"]
      for i in range(21)]
Nb = [data["364113"][regions[i]]["Nb_b"] +
      data["364127"][regions[i]]["Nb_b"] +
      data["364141"][regions[i]]["Nb_b"] +
      data["364155"][regions[i]]["Nb_b"]
      for i in range(21)]
Ma = [data["364113"][regions[i]]["Ma_b"] +
      data["364127"][regions[i]]["Ma_b"] +
      data["364141"][regions[i]]["Ma_b"] +
      data["364155"][regions[i]]["Ma_b"]
      for i in range(21)]
Mb = [data["364113"][regions[i]]["Mb_b"] +
      data["364127"][regions[i]]["Mb_b"] +
      data["364141"][regions[i]]["Mb_b"] +
      data["364155"][regions[i]]["Mb_b"]
      for i in range(21)]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x, Na, label="Na", color="b", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Nb, label="Nb", color="r", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Ma, label="Ma", color="g", marker="o", linestyle="-", linewidth=2)
plt.plot(x, Mb, label="Mb", color="y", marker="o", linestyle="-", linewidth=2)

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("pt 1000+ GeV", fontsize=30)


# calcolo R
R = [0 for i in range(21)]
sigma_R = [0 for i in range(21)]

for i in range(21):
    try:
        R[i] = (Na[i]*Mb[i])/(Nb[i]*Ma[i])
        sigma_R[i] = R[i] * math.sqrt((1/Na[i]) + (1/Nb[i]) + (1/Ma[i]) + (1/Mb[i])) 
    except (ZeroDivisionError, ValueError):
        R[i] = 0
        sigma_R[i] = 0

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, R, yerr=sigma_R, fmt="or", linestyle="-", linewidth=2, label="R_MC") 

plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("R 1000+ GeV", fontsize=30)

plt.hlines(1, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(2, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)

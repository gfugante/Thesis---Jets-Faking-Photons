# %%
import yaml
import matplotlib.pyplot as plt
import math

# %%
with open("Wgamma_pesati.txt", "r") as f:
    Wgamma_pesati = yaml.load(f, Loader=yaml.SafeLoader)
with open("Zgamma_pesati.txt", "r") as f:
    Zgamma_pesati = yaml.load(f, Loader=yaml.SafeLoader)
with open("Znunugamma_pesati.txt", "r") as f:
    Znunugamma_pesati = yaml.load(f, Loader=yaml.SafeLoader)
with open("Wgamma_non_pesati.txt", "r") as f:
    Wgamma_non_pesati = yaml.load(f, Loader=yaml.SafeLoader)
with open("Zgamma_non_pesati.txt", "r") as f:
    Zgamma_non_pesati = yaml.load(f, Loader=yaml.SafeLoader)
with open("Znunugamma_non_pesati.txt", "r") as f:
    Znunugamma_non_pesati = yaml.load(f, Loader=yaml.SafeLoader)

# %%
regions = list(Wgamma_pesati.keys())
x = [i for i in range(21)]

# %% [markdown]
# # Signal Leakage

# %% [markdown]
# ## Eventi pesati

# %% [markdown]
# ## c1

# %%
Wgamma_c1           = [Wgamma_pesati[i]["c1"] for i in regions]
Wgamma_sigma_c1     = [Wgamma_pesati[i]["sigma_c1"] for i in regions]
Zgamma_c1           = [Zgamma_pesati[i]["c1"] for i in regions]
Zgamma_sigma_c1     = [Zgamma_pesati[i]["sigma_c1"] for i in regions]
Znunugamma_c1       = [Znunugamma_pesati[i]["c1"] for i in regions]
Znunugamma_sigma_c1 = [Znunugamma_pesati[i]["sigma_c1"] for i in regions]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c1, yerr=Wgamma_sigma_c1, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c1, yerr=Zgamma_sigma_c1, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c1, yerr=Znunugamma_sigma_c1, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c1", fontsize=30)


# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c1[i] is not 0:
        num = num + Wgamma_c1[i]/pow(Wgamma_sigma_c1[i], 2)
        den = den + 1/pow(Wgamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")


# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c1[i] is not 0:
        num = num + Zgamma_c1[i]/pow(Zgamma_sigma_c1[i], 2)
        den = den + 1/pow(Zgamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c1[i] is not 0:
        num = num + Znunugamma_c1[i]/pow(Znunugamma_sigma_c1[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")


for i in regions:
    print(Wgamma_pesati[i]["Na_s"])
# Out:
# Wgamma
#   c1 = 12.2387 +- 0.301 %
# Zgamma
#   c1 = 6.9588 +- 0.3628 %
# Znunugamma
#   c1 = 6.793 +- 0.1999 %
# 2081.259521484375
# 560.724609375
# 180.98980712890625
# 1520.5218505859375
# 379.736328125
# 4310.17822265625
# 1330.535400390625
# 458.417236328125
# 2979.649658203125
# 872.11279296875
# 0.43471258878707886
# 0.48844507336616516
# 0.5253612995147705
# -0.05373246222734451
# -0.03691619634628296
# 3.5386900901794434
# 1.9916298389434814
# 0.0
# 1.5470601320266724
# 1.9916298389434814
# 698.5046997070312

# %% [markdown]
# ## c2

# %%
Wgamma_c2           = [Wgamma_pesati[i]["c2"] for i in regions]
Wgamma_sigma_c2     = [Wgamma_pesati[i]["sigma_c2"] for i in regions]
Zgamma_c2           = [Zgamma_pesati[i]["c2"] for i in regions]
Zgamma_sigma_c2     = [Zgamma_pesati[i]["sigma_c2"] for i in regions]
Znunugamma_c2       = [Znunugamma_pesati[i]["c2"] for i in regions]
Znunugamma_sigma_c2 = [Znunugamma_pesati[i]["sigma_c2"] for i in regions]

    

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c2, yerr=Wgamma_sigma_c2, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c2, yerr=Zgamma_sigma_c2, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c2, yerr=Znunugamma_sigma_c2, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c2", fontsize=30)

# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c2[i] is not 0:
        num = num + Wgamma_c2[i]/pow(Wgamma_sigma_c2[i], 2)
        den = den + 1/pow(Wgamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")


# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c2[i] is not 0:
        num = num + Zgamma_c2[i]/pow(Zgamma_sigma_c2[i], 2)
        den = den + 1/pow(Zgamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c2[i] is not 0:
        num = num + Znunugamma_c2[i]/pow(Znunugamma_sigma_c2[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")
# Out:
# Wgamma
#   c2 = 3.0076 +- 0.142 %
# Zgamma
#   c2 = 2.5879 +- 0.216 %
# Znunugamma
#   c2 = 2.8534 +- 0.1266 %

# %% [markdown]
# ## c3

# %%
Wgamma_c3           = [Wgamma_pesati[i]["c3"] for i in regions]
Wgamma_sigma_c3     = [Wgamma_pesati[i]["sigma_c3"] for i in regions]
Zgamma_c3           = [Zgamma_pesati[i]["c3"] for i in regions]
Zgamma_sigma_c3     = [Zgamma_pesati[i]["sigma_c3"] for i in regions]
Znunugamma_c3       = [Znunugamma_pesati[i]["c3"] for i in regions]
Znunugamma_sigma_c3 = [Znunugamma_pesati[i]["sigma_c3"] for i in regions]

    

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c3, yerr=Wgamma_sigma_c3, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c3, yerr=Zgamma_sigma_c3, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c3, yerr=Znunugamma_sigma_c3, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c3", fontsize=30)

# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c3[i] is not 0:
        num = num + Wgamma_c3[i]/pow(Wgamma_sigma_c3[i], 2)
        den = den + 1/pow(Wgamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")


# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c3[i] is not 0:
        num = num + Zgamma_c3[i]/pow(Zgamma_sigma_c3[i], 2)
        den = den + 1/pow(Zgamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c3[i] is not 0:
        num = num + Znunugamma_c3[i]/pow(Znunugamma_sigma_c3[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")
# Out:
# Wgamma
#   c3 = 0.5969 +- 0.0625 %
# Zgamma
#   c3 = 0.2396 +- 0.065 %
# Znunugamma
#   c3 = 0.3329 +- 0.0427 %

# %% [markdown]
# ## Non pesati

# %% [markdown]
# ## c1

# %%
Wgamma_c1           = [Wgamma_non_pesati[i]["c1"] for i in regions]
Wgamma_sigma_c1     = [Wgamma_non_pesati[i]["sigma_c1"] for i in regions]
Zgamma_c1           = [Zgamma_non_pesati[i]["c1"] for i in regions]
Zgamma_sigma_c1     = [Zgamma_non_pesati[i]["sigma_c1"] for i in regions]
Znunugamma_c1       = [Znunugamma_non_pesati[i]["c1"] for i in regions]
Znunugamma_sigma_c1 = [Znunugamma_non_pesati[i]["sigma_c1"] for i in regions]



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c1, yerr=Wgamma_sigma_c1, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c1, yerr=Zgamma_sigma_c1, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c1, yerr=Znunugamma_sigma_c1, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c1", fontsize=30)


# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c1[i] is not 0:
        num = num + Wgamma_c1[i]/pow(Wgamma_sigma_c1[i], 2)
        den = den + 1/pow(Wgamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")


# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c1[i] is not 0:
        num = num + Zgamma_c1[i]/pow(Zgamma_sigma_c1[i], 2)
        den = den + 1/pow(Zgamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c1[i] is not 0:
        num = num + Znunugamma_c1[i]/pow(Znunugamma_sigma_c1[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("  c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")
# Out:
# Wgamma
#   c1 = 11.6817 +- 0.0938 %
# Zgamma
#   c1 = 7.0989 +- 0.0926 %
# Znunugamma
#   c1 = 6.4055 +- 0.0143 %

# %% [markdown]
# ## c2

# %%
Wgamma_c2           = [Wgamma_non_pesati[i]["c2"] for i in regions]
Wgamma_sigma_c2     = [Wgamma_non_pesati[i]["sigma_c2"] for i in regions]
Zgamma_c2           = [Zgamma_non_pesati[i]["c2"] for i in regions]
Zgamma_sigma_c2     = [Zgamma_non_pesati[i]["sigma_c2"] for i in regions]
Znunugamma_c2       = [Znunugamma_non_pesati[i]["c2"] for i in regions]
Znunugamma_sigma_c2 = [Znunugamma_non_pesati[i]["sigma_c2"] for i in regions]

    

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c2, yerr=Wgamma_sigma_c2, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c2, yerr=Zgamma_sigma_c2, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c2, yerr=Znunugamma_sigma_c2, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c2", fontsize=30)

# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c2[i] is not 0:
        num = num + Wgamma_c2[i]/pow(Wgamma_sigma_c2[i], 2)
        den = den + 1/pow(Wgamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")

# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c2[i] is not 0:
        num = num + Zgamma_c2[i]/pow(Zgamma_sigma_c2[i], 2)
        den = den + 1/pow(Zgamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c2[i] is not 0:
        num = num + Znunugamma_c2[i]/pow(Znunugamma_sigma_c2[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("  c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")
# Out:
# Wgamma
#   c2 = 3.002 +- 0.0455 %
# Zgamma
#   c2 = 2.8405 +- 0.0573 %
# Znunugamma
#   c2 = 2.9144 +- 0.0095 %

# %% [markdown]
# ## c3

# %%
Wgamma_c3 = []
Wgamma_sigma_c3 = []
Zgamma_c3 = []
Zgamma_sigma_c3 = []
Znunugamma_c3 = []
Znunugamma_sigma_c3 = []



for i in regions:
    Wgamma_c3.append(Wgamma_non_pesati[i]["c3"])
    Wgamma_sigma_c3.append(Wgamma_non_pesati[i]["sigma_c3"])
    Zgamma_c3.append(Zgamma_non_pesati[i]["c3"])
    Zgamma_sigma_c3.append(Zgamma_non_pesati[i]["sigma_c3"])
    Znunugamma_c3.append(Znunugamma_non_pesati[i]["c3"])
    Znunugamma_sigma_c3.append(Znunugamma_non_pesati[i]["sigma_c3"])
    

    

plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, Wgamma_c3, yerr=Wgamma_sigma_c3, fmt="or", linestyle="-", linewidth=2, label="Wgamma")
plt.errorbar([ i+0.05 for i in range(21) ], Zgamma_c3, yerr=Zgamma_sigma_c3, fmt="og", linestyle="-", linewidth=2, label="Zgamma")
plt.errorbar([ i+0.1 for i in range(21) ], Znunugamma_c3, yerr=Znunugamma_sigma_c3, fmt="ob", linestyle="-", linewidth=2, label="Znunugamma")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c3", fontsize=30)

# Wgamma
print("Wgamma")
num = 0;
den = 0;

for i in range(21):
    if Wgamma_sigma_c3[i] is not 0:
        num = num + Wgamma_c3[i]/pow(Wgamma_sigma_c3[i], 2)
        den = den + 1/pow(Wgamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")

# Zgamma
print("Zgamma")
num = 0;
den = 0;

for i in range(21):
    if Zgamma_sigma_c3[i] is not 0:
        num = num + Zgamma_c3[i]/pow(Zgamma_sigma_c3[i], 2)
        den = den + 1/pow(Zgamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")

# Znunugamma
print("Znunugamma")
num = 0;
den = 0;

for i in range(21):
    if Znunugamma_sigma_c3[i] is not 0:
        num = num + Znunugamma_c3[i]/pow(Znunugamma_sigma_c3[i], 2)
        den = den + 1/pow(Znunugamma_sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("  c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")
# Out:
# Wgamma
#   c3 = 0.5807 +- 0.0198 %
# Zgamma
#   c3 = 0.3383 +- 0.0195 %
# Znunugamma
#   c3 = 0.3077 +- 0.003 %

# %% [markdown]
# ## Merging

# %% [markdown]
# ## Pesati

# %%
Na = [Wgamma_pesati[i]["Na_s"] + Zgamma_pesati[i]["Na_s"] + Znunugamma_pesati[i]["Na_s"] for i in regions]
Nb = [Wgamma_pesati[i]["Nb_s"] + Zgamma_pesati[i]["Nb_s"] + Znunugamma_pesati[i]["Nb_s"] for i in regions]
Ma = [Wgamma_pesati[i]["Ma_s"] + Zgamma_pesati[i]["Ma_s"] + Znunugamma_pesati[i]["Ma_s"] for i in regions]
Mb = [Wgamma_pesati[i]["Mb_s"] + Zgamma_pesati[i]["Mb_s"] + Znunugamma_pesati[i]["Mb_s"] for i in regions]


    
print(Na)
c1 = [0 for _ in range(21)]
sigma_c1 = [0 for _ in range(21)]
c2 = [0 for _ in range(21)]
sigma_c2 = [0 for _ in range(21)]
c3 = [0 for _ in range(21)]
sigma_c3 = [0 for _ in range(21)]




c1 = [ Nb[i]/Na[i] for i in range(21) if Na[i]>0 and Nb[i]>0 ]
sigma_c1 = [ c1[i] * math.sqrt((1/Na[i]) + (1/Nb[i])) for i in range(21) if Na[i]>0 and Nb[i]>0 ]

c2 = [ Ma[i]/Na[i] for i in range(21) if Na[i]>0 and Ma[i]>0 ]
sigma_c2 = [ c2[i] * math.sqrt((1/Na[i]) + (1/Ma[i])) for i in range(21) if Na[i]>0 and Ma[i]>0 ]

c3 = [ Mb[i]/Na[i] for i in range(21) if Na[i]>0 and Mb[i]>0 ]
sigma_c3 = [ c3[i] * math.sqrt((1/Na[i]) + (1/Mb[i])) for i in range(21) if Na[i]>0 and Mb[i]>0 ]

Na_pesati = Na
Nb_pesati = Nb
Ma_pesati = Ma
Mb_pesati = Mb
# Out:
# [9948.754104614258, 3065.28399848938, 1045.4135265350342, 6885.634811401367, 2019.566701889038, 4684.671051740646, 1426.286323428154, 485.5599093437195, 3258.391345024109, 940.7210868000984, 1097.4470416903496, 359.14258936047554, 128.1457760334015, 738.3031400963664, 230.9965768456459, 835.7005553245544, 267.2440712451935, 96.56407928466797, 568.4577046632767, 170.6800148487091, 1146.400691986084]

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c1, yerr=sigma_c1, fmt="or", linestyle="-", linewidth=2, label="c1")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c1", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c1[i] is not 0:
        num = num + c1[i]/pow(sigma_c1[i], 2)
        den = den + 1/pow(sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")


plt.hlines(c1_p+sigma_c1_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c1_p-sigma_c1_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c1 = 8.6016 +- 0.155 %

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c2, yerr=sigma_c2, fmt="og", linestyle="-", linewidth=2, label="c2")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c2", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c2[i] is not 0:
        num = num + c2[i]/pow(sigma_c2[i], 2)
        den = den + 1/pow(sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")


plt.hlines(c2_p+sigma_c2_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c2_p-sigma_c2_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c2 = 2.8867 +- 0.0868 %

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c3, yerr=sigma_c3, fmt="ob", linestyle="-", linewidth=2, label="c3")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c3", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c3[i] is not 0:
        num = num + c3[i]/pow(sigma_c3[i], 2)
        den = den + 1/pow(sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")


plt.hlines(c3_p+sigma_c3_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c3_p-sigma_c3_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c3 = 0.4369 +- 0.0334 %

# %% [markdown]
# ## Non pesati

# %%
Na = [Wgamma_non_pesati[i]["Na_s"] + Zgamma_non_pesati[i]["Na_s"] + Znunugamma_non_pesati[i]["Na_s"] for i in regions]
Nb = [Wgamma_non_pesati[i]["Nb_s"] + Zgamma_non_pesati[i]["Nb_s"] + Znunugamma_non_pesati[i]["Nb_s"] for i in regions]
Ma = [Wgamma_non_pesati[i]["Ma_s"] + Zgamma_non_pesati[i]["Ma_s"] + Znunugamma_non_pesati[i]["Ma_s"] for i in regions]
Mb = [Wgamma_non_pesati[i]["Mb_s"] + Zgamma_non_pesati[i]["Mb_s"] + Znunugamma_non_pesati[i]["Mb_s"] for i in regions]

    
print(Na)
c1 = [0 for _ in range(21)]
sigma_c1 = [0 for _ in range(21)]
c2 = [0 for _ in range(21)]
sigma_c2 = [0 for _ in range(21)]
c3 = [0 for _ in range(21)]
sigma_c3 = [0 for _ in range(21)]


c1 = [ Nb[i]/Na[i] for i in range(21) if Na[i]>0 and Nb[i]>0 ]
sigma_c1 = [ c1[i] * math.sqrt((1/Na[i]) + (1/Nb[i])) for i in range(21) if Na[i]>0 and Nb[i]>0 ]

c2 = [ Ma[i]/Na[i] for i in range(21) if Na[i]>0 and Ma[i]>0 ]
sigma_c2 = [ c2[i] * math.sqrt((1/Na[i]) + (1/Ma[i])) for i in range(21) if Na[i]>0 and Ma[i]>0 ]

c3 = [ Mb[i]/Na[i] for i in range(21) if Na[i]>0 and Mb[i]>0 ]
sigma_c3 = [ c3[i] * math.sqrt((1/Na[i]) + (1/Mb[i])) for i in range(21) if Na[i]>0 and Mb[i]>0 ]
# Out:
# [1441879.0, 466269.0, 161568.0, 975610.0, 304701.0, 50022.0, 15556.0, 5187.0, 34466.0, 10369.0, 17186.0, 5705.0, 2038.0, 11481.0, 3667.0, 12939.0, 4297.0, 1600.0, 8642.0, 2697.0, 60234.0]

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c1, yerr=sigma_c1, fmt="or", linestyle="-", linewidth=2, label="c1")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c1", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c1[i] is not 0:
        num = num + c1[i]/pow(sigma_c1[i], 2)
        den = den + 1/pow(sigma_c1[i], 2)

c1_p = num/den
sigma_c1_p = math.sqrt(1/den)
print("c1 = " + repr(round(100*c1_p, 4)) + " +- " + repr(round(100*sigma_c1_p, 4)) + " %")

plt.hlines(c1_p+sigma_c1_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c1_p-sigma_c1_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c1 = 6.5736 +- 0.014 %

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c2, yerr=sigma_c2, fmt="og", linestyle="-", linewidth=2, label="c2")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c2", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c2[i] is not 0:
        num = num + c2[i]/pow(sigma_c2[i], 2)
        den = den + 1/pow(sigma_c2[i], 2)

c2_p = num/den
sigma_c2_p = math.sqrt(1/den)
print("c2 = " + repr(round(100*c2_p, 4)) + " +- " + repr(round(100*sigma_c2_p, 4)) + " %")


plt.hlines(c2_p+sigma_c2_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c2_p-sigma_c2_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c2 = 2.9164 +- 0.0091 %

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar(x, c3, yerr=sigma_c3, fmt="ob", linestyle="-", linewidth=2, label="c3")


plt.xticks(range(len(regions)), regions)
plt.legend(fontsize="xx-large")
plt.title("Signal Leakage c3", fontsize=30)

# media pesata sugli errori

num = 0;
den = 0;

for i in range(21):
    if sigma_c3[i] is not 0:
        num = num + c3[i]/pow(sigma_c3[i], 2)
        den = den + 1/pow(sigma_c3[i], 2)

c3_p = num/den
sigma_c3_p = math.sqrt(1/den)
print("c3 = " + repr(round(100*c3_p, 4)) + " +- " + repr(round(100*sigma_c3_p, 4)) + " %")


plt.hlines(c3_p+sigma_c3_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
plt.hlines(c3_p-sigma_c3_p, 0, 21, colors='gray', linestyles='solid', label='', linewidth=0.5)
# Out:
# c3 = 0.3168 +- 0.003 %

# %% [markdown]
# ### Merging SR + 2muCR + 2eCR di Zjets + Wjets (1mu e gammajet da sole)

# %%
# SR + 2muCR + 2eCR
Na_m = [Na_pesati[i] + Na_pesati[i+10] + Na_pesati[i+15] for i in range(5)]
Nb_m = [Nb_pesati[i] + Nb_pesati[i+10] + Nb_pesati[i+15] for i in range(5)]
Ma_m = [Ma_pesati[i] + Ma_pesati[i+10] + Ma_pesati[i+15] for i in range(5)]
Mb_m = [Mb_pesati[i] + Mb_pesati[i+10] + Mb_pesati[i+15] for i in range(5)]


# SR + 2muCR + 2eCR
c1_m = [0 for _ in range(5)]
sigma_c1_m = [0 for _ in range(5)]
c2_m = [0 for _ in range(5)]
sigma_c2_m = [0 for _ in range(5)]
c3_m = [0 for _ in range(5)]
sigma_c3_m = [0 for _ in range(5)]




c1_m = [ Nb_m[i]/Na_m[i] for i in range(5) if Na_m[i]>0 and Nb_m[i]>0 ]
sigma_c1_m = [ c1_m[i] * math.sqrt((1/Na_m[i]) + (1/Nb_m[i])) for i in range(5) if Na_m[i]>0 and Nb_m[i]>0 ]

c2_m = [ Ma_m[i]/Na_m[i] for i in range(5) if Na_m[i]>0 and Ma_m[i]>0 ]
sigma_c2_m = [ c2_m[i] * math.sqrt((1/Na_m[i]) + (1/Ma_m[i])) for i in range(5) if Na_m[i]>0 and Ma_m[i]>0 ]

c3_m = [ Mb_m[i]/Na_m[i] for i in range(5) if Na_m[i]>0 and Mb_m[i]>0 ]
sigma_c3_m = [ c3_m[i] * math.sqrt((1/Na_m[i]) + (1/Mb_m[i])) for i in range(5) if Na_m[i]>0 and Mb_m[i]>0 ]




# solo 1muCR

Na_n = [Na_pesati[i+5] for i in range(5)]
Nb_n = [Nb_pesati[i+5] for i in range(5)]
Ma_n = [Ma_pesati[i+5] for i in range(5)]
Mb_n = [Mb_pesati[i+5] for i in range(5)]


c1_n = [0 for _ in range(5)]
sigma_c1_n = [0 for _ in range(5)]
c2_n = [0 for _ in range(5)]
sigma_c2_n = [0 for _ in range(5)]
c3_n = [0 for _ in range(5)]
sigma_c3_n = [0 for _ in range(5)]




c1_n = [ Nb_n[i]/Na_n[i] for i in range(5) if Na_n[i]>0 and Nb_n[i]>0 ]
sigma_c1_n = [ c1_n[i] * math.sqrt((1/Na_n[i]) + (1/Nb_n[i])) for i in range(5) if Na_n[i]>0 and Nb_n[i]>0 ]

c2_n = [ Ma_n[i]/Na_n[i] for i in range(5) if Na_n[i]>0 and Ma_n[i]>0 ]
sigma_c2_n = [ c2_n[i] * math.sqrt((1/Na_n[i]) + (1/Ma_n[i])) for i in range(5) if Na_n[i]>0 and Ma_n[i]>0 ]

c3_n = [ Mb_n[i]/Na_n[i] for i in range(5) if Na_n[i]>0 and Mb_n[i]>0 ]
sigma_c3_n = [ c3_n[i] * math.sqrt((1/Na_n[i]) + (1/Mb_n[i])) for i in range(5) if Na_n[i]>0 and Mb_n[i]>0 ]


# solo gammajet
Na_g = Na_pesati[20]
Nb_g = Nb_pesati[20]
Ma_g = Ma_pesati[20]
Mb_g = Mb_pesati[20]

c1_g = Nb_g/Na_g 
sigma_c1_g = c1_g * math.sqrt((1/Na_g) + (1/Nb_g))

c2_g = Ma_g/Na_g 
sigma_c2_g = c2_g * math.sqrt((1/Na_g) + (1/Ma_g))

c3_g = Mb_g/Na_g 
sigma_c3_g = c3_g * math.sqrt((1/Na_g) + (1/Mb_g))



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar([ i for i in range(5) ], c1_n, yerr=sigma_c1_n, fmt="or", linestyle="-", linewidth=2, label="SR + 2muCR + 2eCR") 
plt.errorbar([ i+0.05 for i in range(5) ], c1_m, yerr=sigma_c1_m, fmt="ob", linestyle="-", linewidth=2, label="1muCR")
plt.errorbar(0, c1_g, yerr=sigma_c1_g, fmt="og", linestyle="-", linewidth=2, label="gammajetCR") 

plt.xticks(range(5), ["ISR1", "ISR2", "ISR3", "ESR1", "ESR2"])
plt.legend(fontsize="xx-large")
plt.title("c1", fontsize=30)



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar([ i for i in range(5) ], c2_n, yerr=sigma_c2_n, fmt="or", linestyle="-", linewidth=2, label="SR + 2muCR + 2eCR") 
plt.errorbar([ i+0.05 for i in range(5) ], c2_m, yerr=sigma_c2_m, fmt="ob", linestyle="-", linewidth=2, label="1muCR")
plt.errorbar(0, c2_g, yerr=sigma_c2_g, fmt="og", linestyle="-", linewidth=2, label="gammajetCR") 

plt.xticks(range(5), ["ISR1", "ISR2", "ISR3", "ESR1", "ESR2"])
plt.legend(fontsize="xx-large")
plt.title("c2", fontsize=30)



plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar([ i for i in range(5) ], c3_n, yerr=sigma_c3_n, fmt="or", linestyle="-", linewidth=2, label="SR + 2muCR + 2eCR") 
plt.errorbar([ i+0.05 for i in range(5) ], c3_m, yerr=sigma_c3_m, fmt="ob", linestyle="-", linewidth=2, label="1muCR")
plt.errorbar(0, c3_g, yerr=sigma_c3_g, fmt="og", linestyle="-", linewidth=2, label="gammajetCR") 

plt.xticks(range(5), ["ISR1", "ISR2", "ISR3", "ESR1", "ESR2"])
plt.legend(fontsize="xx-large")
plt.title("c3", fontsize=30)
# Out:
# Text(0.5, 1.0, 'c3')

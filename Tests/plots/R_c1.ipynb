# %%
import matplotlib.pyplot as plt

# %%
Wjets = {'mean': [1.35292, 1.90311, 1.94241], 'sigma': [0.04253, 0.107265, 0.15216]}
Zjets = {'mean': [1.76502, 2.23763, 2.31546], 'sigma': [0.089455, 0.204712, 0.300561]}

Wgamma = {'mean': [0.119301, 0.0965114, 0.0782464], 'sigma': [0.00206927, 0.00350642, 0.00392235]}
Zgamma = {'mean': [0.110774, 0.0949759, 0.0828379], 'sigma': [0.00571281, 0.0100271, 0.0120437]}
gammajets = {'mean': [0.275674, 0.261278, 0.235096], 'sigma': [0.000804004, 0.00149668, 0.00167509]}
Znunugamma = {'mean': [0.0923227, 0.0844581, 0.0736637], 'sigma': [0.00295565, 0.00551113, 0.00661201]}

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar([ i - 0.02 for i in range(3) ], Wjets['mean'], yerr=Wjets['sigma'], fmt='r', marker='o', linestyle='', linewidth=2, label='Wjets')
plt.errorbar([ i + 0.02 for i in range(3) ], Zjets['mean'], yerr=Zjets['sigma'], fmt='b', marker='o', linestyle='', linewidth=2, label='Zjets')

plt.xticks(range(3), ["pt 150-225 GeV", "pt 225-300 GeV", "pt 300+ GeV"], fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize="xx-large")
plt.grid()


plt.ylabel('R    ', rotation=0, fontsize=30)
# Out:
# Text(0, 0.5, 'R    ')

# %%
plt.figure(num=None, figsize=(30, 12), dpi=80, facecolor='w', edgecolor='k')

plt.errorbar([ i - 0.02 for i in range(3) ], Wgamma['mean'], yerr=Wgamma['sigma'], fmt='r', marker='o', linestyle='', linewidth=2, label='Wgamma')
plt.errorbar([ i + 0.02 for i in range(3) ], Zgamma['mean'], yerr=Zgamma['sigma'], fmt='b', marker='o', linestyle='', linewidth=2, label='Zgamma')
plt.errorbar([ i - 0.04 for i in range(3) ], Znunugamma['mean'], yerr=Znunugamma['sigma'], fmt='g', marker='o', linestyle='', linewidth=2, label='Znunugamma')
plt.errorbar([ i + 0.04 for i in range(3) ], gammajets['mean'], yerr=gammajets['sigma'], fmt='orangered', marker='o', linestyle='', linewidth=2, label='gammajets')




plt.xticks(range(3), ["pt 150-225 GeV", "pt 225-300 GeV", "pt 300+ GeV"], fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize="xx-large")
plt.grid()


plt.ylabel('c1    ', rotation=0, fontsize=30)
# Out:
# Text(0, 0.5, 'c1    ')
